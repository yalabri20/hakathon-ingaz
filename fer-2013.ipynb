# %%
# !pip install -U -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
# Out:
# ...
#   Using cached torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.0 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.0 MB 2.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.0 MB 2.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.0 MB 3.2 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.0 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.0 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.0 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 3.8 MB/s eta 0:00:01
# ...

# %%
# !pip install tensorboard

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -U -r requirements.txt
# Out:
# C:\Users\User\anaconda_projects\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...
#   Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data '' --cfg yolov5s.yaml --weights yolov5s.pt --name emotion_detection --hyp hyp.scratch.yaml --train train --val test --nc 7 --names '["angry" , "disgust"," fear","happy","neutral", "sad","suprise"]'
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--imgsz IMGSZ]
#                 [--rect] [--resume [RESUME]] [--nosave] [--noval]
#                 [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--evolve_population EVOLVE_POPULATION]
#                 [--resume_evolve RESUME_EVOLVE] [--bucket BUCKET]
#                 [--cache [CACHE]] [--image-weights] [--device DEVICE]
#                 [--multi-scale] [--single-cls] [--optimizer {SGD,Adam,AdamW}]
#                 [--sync-bn] [--workers WORKERS] [--project PROJECT]
#                 [--name NAME] [--exist-ok] [--quad] [--cos-lr]
#                 [--label-smoothing LABEL_SMOOTHING] [--patience PATIENCE]
#                 [--freeze FREEZE [FREEZE ...]] [--save-period SAVE_PERIOD]
#                 [--seed SEED] [--local_rank LOCAL_RANK] [--entity ENTITY]
#                 [--upload_dataset [UPLOAD_DATASET]]
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train
# Out:
#       <iframe id="tensorboard-frame-93a467302bc881dd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-93a467302bc881dd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !pip install opencv-python
# !pip install opencv-python-headless
# !pip install keras
# !pip install tensorflow

# %%
import cv2
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# تحميل نموذج FER-2013 المدرب مسبقًا
model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا

# قائمة الفئات المحتملة لتعبيرات الوجه
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# تهيئة الكاميرا
cap = cv2.VideoCapture(0)

# تحميل مصنف الوجه من OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    # قراءة الصورة من الكاميرا
    ret, frame = cap.read()
    
    # تحويل الصورة إلى تدرج الرمادي
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # الكشف عن الوجوه
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    
    for (x, y, w, h) in faces:
        # استخراج الوجه
        face = frame[y:y+h, x:x+w]
        
        # تحويل الوجه إلى الحجم المطلوب (48x48) كما هو مطلوب للنموذج المدرب
        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face_resized = cv2.resize(face_rgb, (48, 48))
        face_array = img_to_array(face_resized)
        face_array = np.expand_dims(face_array, axis=0)
        face_array /= 255  # تطبيع الصورة
        
        # التنبؤ بتعبير الوجه
        emotion_predictions = model.predict(face_array)
        max_index = np.argmax(emotion_predictions[0])
        predicted_emotion = emotion_labels[max_index]
        
        # رسم مستطيل حول الوجه مع النص لتعبير الوجه
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, predicted_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    # عرض الصورة مع تعبير الوجه المكتشف
    cv2.imshow('Emotion Detection', frame)
    
    # كسر الحلقة إذا ضغطت على مفتاح 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# إغلاق الكاميرا وإغلاق النوافذ
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 from keras.models import load_model
#       4 from tensorflow.keras.preprocessing.image import img_to_array
#       5 import matplotlib.pyplot as plt
#
# File ~\anaconda3\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~\anaconda3\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# ...

# %%
# !pip uninstall pandas -y
# !pip install pandas
# Out:
# Found existing installation: pandas 2.2.3
# Uninstalling pandas-2.2.3:
#   Successfully uninstalled pandas-2.2.3
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\User\anaconda3\Lib\site-packages\~andas.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\User\anaconda3\Lib\site-packages\~andas'.
# You can safely remove it manually.
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, but you have pillow 11.1.0 which is incompatible.

# %%
import cv2
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# تحميل نموذج FER-2013 المدرب مسبقًا
model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا

# قائمة الفئات المحتملة لتعبيرات الوجه
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# تهيئة الكاميرا
cap = cv2.VideoCapture(0)

# تحميل مصنف الوجه من OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    # قراءة الصورة من الكاميرا
    ret, frame = cap.read()
    
    # تحويل الصورة إلى تدرج الرمادي
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # الكشف عن الوجوه
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    
    for (x, y, w, h) in faces:
        # استخراج الوجه
        face = frame[y:y+h, x:x+w]
        
        # تحويل الوجه إلى الحجم المطلوب (48x48) كما هو مطلوب للنموذج المدرب
        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face_resized = cv2.resize(face_rgb, (48, 48))
        face_array = img_to_array(face_resized)
        face_array = np.expand_dims(face_array, axis=0)
        face_array /= 255  # تطبيع الصورة
        
        # التنبؤ بتعبير الوجه
        emotion_predictions = model.predict(face_array)
        max_index = np.argmax(emotion_predictions[0])
        predicted_emotion = emotion_labels[max_index]
        
        # رسم مستطيل حول الوجه مع النص لتعبير الوجه
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, predicted_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    # عرض الصورة مع تعبير الوجه المكتشف
    cv2.imshow('Emotion Detection', frame)
    
    # كسر الحلقة إذا ضغطت على مفتاح 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# إغلاق الكاميرا وإغلاق النوافذ
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 from keras.models import load_model
#       4 from tensorflow.keras.preprocessing.image import img_to_array
#       5 import matplotlib.pyplot as plt
#
# File ~\anaconda3\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~\anaconda3\Lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import cv2
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# تحميل نموذج FER-2013 المدرب مسبقًا
model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا

# قائمة الفئات المحتملة لتعبيرات الوجه
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# تهيئة الكاميرا
cap = cv2.VideoCapture(0)

# تحميل مصنف الوجه من OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    # قراءة الصورة من الكاميرا
    ret, frame = cap.read()
    
    # تحويل الصورة إلى تدرج الرمادي
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # الكشف عن الوجوه
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    
    for (x, y, w, h) in faces:
        # استخراج الوجه
        face = frame[y:y+h, x:x+w]
        
        # تحويل الوجه إلى الحجم المطلوب (48x48) كما هو مطلوب للنموذج المدرب
        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face_resized = cv2.resize(face_rgb, (48, 48))
        face_array = img_to_array(face_resized)
        face_array = np.expand_dims(face_array, axis=0)
        face_array /= 255  # تطبيع الصورة
        
        # التنبؤ بتعبير الوجه
        emotion_predictions = model.predict(face_array)
        max_index = np.argmax(emotion_predictions[0])
        predicted_emotion = emotion_labels[max_index]
        
        # رسم مستطيل حول الوجه مع النص لتعبير الوجه
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, predicted_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    # عرض الصورة مع تعبير الوجه المكتشف
    cv2.imshow('Emotion Detection', frame)
    
    # كسر الحلقة إذا ضغطت على مفتاح 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# إغلاق الكاميرا وإغلاق النوافذ
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       5 import matplotlib.pyplot as plt
#       7 # تحميل نموذج FER-2013 المدرب مسبقًا
# ----> 8 model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا
#      10 # قائمة الفئات المحتملة لتعبيرات الوجه
#      11 emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()

# إضافة طبقة الإدخال بشكل صحيح
model.add(Input(shape=(48, 48, 1)))

# إضافة طبقة Convolution
model.add(Conv2D(32, (3, 3), padding='same'))

# إضافة طبقات أخرى
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(7, activation='softmax'))  # تصنيف 7 فئات للتعبيرات الوجهية

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18432)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,359,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# ...

# %%
import cv2
import numpy as np
from keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# تحميل نموذج FER-2013 المدرب مسبقًا
model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا

# قائمة الفئات المحتملة لتعبيرات الوجه
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# تهيئة الكاميرا
cap = cv2.VideoCapture(0)

# تحميل مصنف الوجه من OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    # قراءة الصورة من الكاميرا
    ret, frame = cap.read()
    
    # تحويل الصورة إلى تدرج الرمادي
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # الكشف عن الوجوه
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    
    for (x, y, w, h) in faces:
        # استخراج الوجه
        face = frame[y:y+h, x:x+w]
        
        # تحويل الوجه إلى الحجم المطلوب (48x48) كما هو مطلوب للنموذج المدرب
        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face_resized = cv2.resize(face_rgb, (48, 48))
        face_array = img_to_array(face_resized)
        face_array = np.expand_dims(face_array, axis=0)
        face_array /= 255  # تطبيع الصورة
        
        # التنبؤ بتعبير الوجه
        emotion_predictions = model.predict(face_array)
        max_index = np.argmax(emotion_predictions[0])
        predicted_emotion = emotion_labels[max_index]
        
        # رسم مستطيل حول الوجه مع النص لتعبير الوجه
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, predicted_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    # عرض الصورة مع تعبير الوجه المكتشف
    cv2.imshow('Emotion Detection', frame)
    
    # كسر الحلقة إذا ضغطت على مفتاح 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# إغلاق الكاميرا وإغلاق النوافذ
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 8
#       5 import matplotlib.pyplot as plt
#       7 # تحميل نموذج FER-2013 المدرب مسبقًا
# ----> 8 model = load_model('model_v6_23.hdf5')  # تأكد من تحميل النموذج المدرب مسبقًا
#      10 # قائمة الفئات المحتملة لتعبيرات الوجه
#      11 emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
# ...

# %%
model = load_model('model_v6_23.hdf5', custom_objects=None)  # تحميل النموذج
model.build(input_shape=(3, 3, 1, 32))  # تحديد شكل المدخلات هنا
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model = load_model('model_v6_23.hdf5', custom_objects=None)  # تحميل النموذج
#       2 model.build(input_shape=(3, 3, 1, 32))
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
# ...

# %%
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(48, 48, 1)))  # مثال لتحديد المدخلات
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.add(Conv2D(32, (3, 3), padding='same', input_shape=(48, 48, 1)))
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:122, in Sequential.add(self, layer, rebuild)
#     120 self._layers.append(layer)
#     121 if rebuild:
# --> 122     self._maybe_rebuild()
#     123 else:
#     124     self.built = False
#
# File ~\anaconda3\Lib\site-packages\keras\src\models\sequential.py:141, in Sequential._maybe_rebuild(self)
#     139 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     140     input_shape = self._layers[0].batch_shape
# --> 141     self.build(input_shape)
#     142 elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     143     # We can build the Sequential model if the first layer has the
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models  import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D , MaxPooling2D
from keras import backend as K
import os



# img = load_img('path/to/image.jpg')



# train_data = 'data/train'
# test_data = 'data/test'

# Replace the above line with:
train_data = os.path.join(os.getcwd(),  'train')
test_data = os.path.join(os.getcwd(),  'test')

train_datagen  =  ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest')



validation_datagen = ImageDataGenerator(
    rescale=1./255
)


train_generator = train_datagen.flow_from_directory(
    train_data, 
    color_mode='grayscale', 
    target_size=(48,48),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator  = validation_datagen.flow_from_directory(
    test_data, 
    color_mode='grayscale', 
    target_size=(48,48), 
    batch_size=32, 
    class_mode='categorical',
    shuffle=True)



class_labels = ['Angry', 'Disgust', 'Fear','Happy', 'Neutral','Sad','Suprise']

# img , label = train_generator.__next__()

img , label  = next(train_generator)
model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), activation ='relu', input_shape = (48,48,1)))
model.add(Conv2D(64, kernel_size =(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size =(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))


model.add(Conv2D(256, kernel_size =(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1))


model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))


model.add(Dense(7,activation='softmax'))   #  since it is a categorical   we are using softmazx, we use the sigmoifd for the binary   classification 

model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

print(model.summary())



train_path = 'data/train'

test_path = 'data/test'

num_train_imgs = 0


for root , dirs , files in os.walk(train_path):
    num_train_imgs +=len(files)

num_test_imgs = 0 
for root ,dirs, files in os.walk(test_path): 
    num_test_imgs +=len(files)   #counting the number of the images 


print(num_test_imgs)    #Number of the test images
print(num_train_imgs)    #Number od the train images 

epochs = 30 
history = model.fit(
                    train_generator, 
                    steps_per_epoch=num_train_imgs//32,
                    epochs = epochs, 
                    validation_data=validation_generator,
                    validation_steps=num_test_imgs//32)




model.save('model_file.h5')
# Plot the loss and accuracy curves for training and validation
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7174 images belonging to 7 classes.
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 44, 44, 64)     │        18,496 │
# ...

# %%
import cv2
import numpy as np
from keras.models import load_model

model=load_model('model_file.h5')

faceDetect=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

labels_dict={0:'Angry',1:'Disgust', 2:'Fear', 3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# len(number_of_image), image_height, image_width, channel

frame=cv2.imread("emotion.jpeg")
gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces= faceDetect.detectMultiScale(gray, 1.3, 3)
for x,y,w,h in faces:
    sub_face_img=gray[y:y+h, x:x+w]
    resized=cv2.resize(sub_face_img,(48,48))
    normalize=resized/255.0
    reshaped=np.reshape(normalize, (1, 48, 48, 1))
    result=model.predict(reshaped)
    label=np.argmax(result, axis=1)[0]
    print(label)
    cv2.rectangle(frame, (x,y), (x+w, y+h), (0,0,255), 1)
    cv2.rectangle(frame,(x,y),(x+w,y+h),(50,50,255),2)
    cv2.rectangle(frame,(x,y-40),(x+w,y),(50,50,255),-1)
    cv2.putText(frame, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
cv2.imshow("Frame",frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ...

# %%
import nest_asyncio
from telegram import Update
from telegram.ext import Application, MessageHandler, filters, CallbackContext
import asyncio
import cv2
import numpy as np
from keras.models import load_model

# التوكن الخاص بالبوت
TOKEN = '7869587173:AAFumCLEwgKBIvfULtV5yJbgi8qfOzIupWk'  # ضع هنا التوكن الخاص بك
chat_id = '-4727808702'  # ضع هنا معرف المستخدم أو مجموعة الدردشة التي تريد إرسال الرسائل لها

# تحميل نموذج التعرف على العواطف
model = load_model('model_file.h5')

# تحميل كاشف الوجه
faceDetect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# معجم لتخزين التسميات الخاصة بالتعبيرات
labels_dict = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# دالة لإرسال الفيديو عبر البوت
async def send_video_report(application, video_path):
    with open(video_path, 'rb') as video:
        await application.bot.send_video(chat_id=chat_id, video=video)

# دالة لتحليل الفيديو واكتشاف التعبيرات
def detect_emotion_from_video(video_path):
    # فتح الفيديو باستخدام OpenCV
    cap = cv2.VideoCapture(video_path)
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceDetect.detectMultiScale(gray, 1.3, 3)
        
        detected_emotions = []
        for x, y, w, h in faces:
            sub_face_img = gray[y:y+h, x:x+w]
            resized = cv2.resize(sub_face_img, (48, 48))
            normalize = resized / 255.0
            reshaped = np.reshape(normalize, (1, 48, 48, 1))
            result = model.predict(reshaped)
            label = np.argmax(result, axis=1)[0]
            
            emotion = labels_dict[label]
            detected_emotions.append(emotion)
            
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 1)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (50, 50, 255), 2)
            cv2.rectangle(frame, (x, y-40), (x+w, y), (50, 50, 255), -1)
            cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        # عرض الفيديو أثناء التحليل
        cv2.imshow("Video Frame", frame)
        
        # عند الضغط على مفتاح "q" سيتم إغلاق الفيديو
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # إنهاء قراءة الفيديو
    cap.release()
    cv2.destroyAllWindows()

    return detected_emotions

# دالة لإرسال تقارير التحليل
async def send_report(application, video_path):
    detected_emotions = detect_emotion_from_video(video_path)
    
    for emotion in detected_emotions:
        # إرسال تقرير عبر البوت
        await application.bot.send_message(chat_id=chat_id, text=f"تم اكتشاف تعبير الوجه: {emotion}")

# دالة لتكرار الرسائل التي يرسلها المستخدم
async def echo(update: Update, context: CallbackContext) -> None:
    await update.message.reply_text(f'قلت: {update.message.text}')

# الدالة الرئيسية
async def main():
    # إنشاء التطبيق (بوت Telegram)
    application = Application.builder().token(TOKEN).build()

    # إضافة المعالج لتكرار الرسائل
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, echo))

    # تحديد مسار الفيديو
    video_path = 'reciservice.mp4'  # ضع هنا المسار الصحيح للفيديو
    
    # بدء إرسال التقارير بعد تحليل الفيديو
    await send_report(application, video_path)

    # بدء البوت
    await application.run_polling()

# تشغيل التطبيق
if __name__ == "__main__":
    nest_asyncio.apply()  # يسمح بتشغيل الـ event loop في بيئات مثل Jupyter أو Colab
    await main()  # بدء تشغيل البوت

# %%
import nest_asyncio
from telegram import Update
from telegram.ext import Application, MessageHandler, filters, CallbackContext
import asyncio
import cv2
import numpy as np
from keras.models import load_model

# التوكن الخاص بالبوت
TOKEN = '7869587173:AAFumCLEwgKBIvfULtV5yJbgi8qfOzIupWk'  # ضع هنا التوكن الخاص بك
chat_id = '672355156'  # ضع هنا معرف المستخدم أو مجموعة الدردشة التي تريد إرسال الرسائل لها

# تحميل نموذج التعرف على العواطف
model = load_model('model_file.h5')

# تحميل كاشف الوجه
faceDetect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# معجم لتخزين التسميات الخاصة بالتعبيرات
labels_dict = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# دالة لإرسال رسالة عبر البوت
async def send_emotion_report(application, emotion):
    # إرسال رسالة تحتوي على التعبير الذي تم اكتشافه
    await application.bot.send_message(chat_id=chat_id, text=f"تم اكتشاف تعبير الوجه: {emotion}")

# دالة لتكرار الرسائل التي يرسلها المستخدم
async def echo(update: Update, context: CallbackContext) -> None:
    await update.message.reply_text(f'قلت: {update.message.text}')

# دالة لتحليل الصورة واكتشاف التعبيرات
def detect_emotion():
    frame = cv2.imread("emotion.jpeg")
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceDetect.detectMultiScale(gray, 1.3, 3)
    
    detected_emotions = []
    for x, y, w, h in faces:
        sub_face_img = gray[y:y+h, x:x+w]
        resized = cv2.resize(sub_face_img, (48, 48))
        normalize = resized / 255.0
        reshaped = np.reshape(normalize, (1, 48, 48, 1))
        result = model.predict(reshaped)
        label = np.argmax(result, axis=1)[0]
        
        emotion = labels_dict[label]
        detected_emotions.append(emotion)
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 1)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (50, 50, 255), 2)
        cv2.rectangle(frame, (x, y-40), (x+w, y), (50, 50, 255), -1)
        cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
    
    cv2.imshow("Frame", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    return detected_emotions

# الدالة الرئيسية
async def main():
    # إنشاء التطبيق (بوت Telegram)
    application = Application.builder().token(TOKEN).build()

    # إضافة المعالج لتكرار الرسائل
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, echo))

    # تحليل العواطف وإرسال رسالة عند اكتشاف أي تعبير
    detected_emotions = detect_emotion()
    for emotion in detected_emotions:
        # إرسال تقرير عبر البوت
        await send_emotion_report(application, emotion)
    
    # بدء البوت
    await application.run_polling()

# تشغيل التطبيق
if __name__ == "__main__":
    nest_asyncio.apply()  # يسمح بتشغيل الـ event loop في بيئات مثل Jupyter أو Colab
    await main()  # بدء تشغيل البوت
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# ...

# %%
pip install python-telegram-bot
# Out:
# ...
#    ---------------------------------------- 0.0/669.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/669.5 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/669.5 kB ? eta -:--:--
#    ------------------------------- -------- 524.3/669.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 669.5/669.5 kB 1.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
from telegram import Update
from telegram.ext import Application, MessageHandler, filters, CallbackContext
import asyncio
import cv2
import numpy as np
from keras.models import load_model

# التوكن الخاص بالبوت
TOKEN = '7869587173:AAFumCLEwgKBIvfULtV5yJbgi8qfOzIupWk'  # ضع هنا التوكن الخاص بك
chat_id = '672355156'  # ضع هنا معرف المستخدم أو مجموعة الدردشة التي تريد إرسال الرسائل لها

# تحميل نموذج التعرف على العواطف
model = load_model('model_file.h5')

# تحميل كاشف الوجه
faceDetect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# معجم لتخزين التسميات الخاصة بالتعبيرات
labels_dict = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Neutral', 5: 'Sad', 6: 'Surprise'}

# دالة لإرسال رسالة عبر البوت
async def send_emotion_report(application, emotion):
    # إرسال رسالة تحتوي على التعبير الذي تم اكتشافه
    await application.bot.send_message(chat_id=chat_id, text=f"تم اكتشاف تعبير الوجه: {emotion}")

# دالة لتكرار الرسائل التي يرسلها المستخدم
async def echo(update: Update, context: CallbackContext) -> None:
    await update.message.reply_text(f'قلت: {update.message.text}')

# دالة لتحليل الفيديو واكتشاف التعبيرات
def detect_emotion_from_video():
    # فتح الفيديو (يمكنك تغيير المسار هنا إلى مسار الفيديو الذي ترغب في معالجته)
    video_capture = cv2.VideoCapture("reciservice.mp4")  # 0 يشير إلى الكاميرا الافتراضية (أو استبدل برابط فيديو)

    while True:
        # قراءة الإطار التالي من الفيديو
        ret, frame = video_capture.read()
        if not ret:
            break
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceDetect.detectMultiScale(gray, 1.3, 3)
        
        detected_emotions = []
        for x, y, w, h in faces:
            sub_face_img = gray[y:y+h, x:x+w]
            resized = cv2.resize(sub_face_img, (48, 48))
            normalize = resized / 255.0
            reshaped = np.reshape(normalize, (1, 48, 48, 1))
            result = model.predict(reshaped)
            label = np.argmax(result, axis=1)[0]
            
            emotion = labels_dict[label]
            detected_emotions.append(emotion)
            
            # رسم مستطيل حول الوجه وكتابة التعبير
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 1)
            cv2.rectangle(frame, (x, y), (x+w, y+h), (50, 50, 255), 2)
            cv2.rectangle(frame, (x, y-40), (x+w, y), (50, 50, 255), -1)
            cv2.putText(frame, emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        # عرض الإطار في نافذة
        cv2.imshow("Frame", frame)

        # إيقاف الفيديو عند الضغط على مفتاح 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        # إرسال التقرير إذا تم اكتشاف تعبير
        for emotion in detected_emotions:
            asyncio.run(send_emotion_report(application, emotion))

    # إغلاق الفيديو
    video_capture.release()
    cv2.destroyAllWindows()

# الدالة الرئيسية
async def main():
    # إنشاء التطبيق (بوت Telegram)
    application = Application.builder().token(TOKEN).build()

    # إضافة المعالج لتكرار الرسائل
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, echo))

    # بدء عملية كشف التعبيرات من الفيديو
    detect_emotion_from_video()

    # بدء البوت
    await application.run_polling()

# تشغيل التطبيق
if __name__ == "__main__":
    nest_asyncio.apply()  # يسمح بتشغيل الـ event loop في بيئات مثل Jupyter أو Colab
    await main()  # بدء تشغيل البوت
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 95
#      93 if __name__ == "__main__":
#      94     nest_asyncio.apply()  # يسمح بتشغيل الـ event loop في بيئات مثل Jupyter أو Colab
# ---> 95     await main()
#
# Cell In[1], line 87, in main()
#      84 application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, echo))
#      86 # بدء عملية كشف التعبيرات من الفيديو
# ---> 87 detect_emotion_from_video()
#      89 # بدء البوت
#      90 await application.run_polling()
#
# Cell In[1], line 72, in detect_emotion_from_video()
#      70     # إرسال التقرير إذا تم اكتشاف تعبير
#      71     for emotion in detected_emotions:
# ...

# %%
pip install python-telegram-bot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
